# %% [markdown]
# # PML-CAP6-Classification Nearest Neighbors

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pylab import rcParams
df=pd.read_csv('csv/teleCust1000t.csv')
df.head(9)
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
# 5       2      41   39        0       17    78.0   2      16     0.0       1
# 6       3      45   22        1        2    19.0   2       4     0.0       1
# 7       2      38   35        0        5    76.0   2      10     0.0       0
# 8       3      45   59        1        7   166.0   4      31     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3
# 5       1        3
# 6       5        2
# 7       3        4
# ...

# %% [markdown]
# ### Heat Map Correlation

# %%
rcParams['figure.figsize']=[10,10]
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Separate Variables

# %%
print(df.columns)
X=df[['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed',
       'employ', 'retire', 'gender', 'reside']]
Y=df['custcat']
# Out:
# Index(['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed',
#        'employ', 'retire', 'gender', 'reside', 'custcat'],
#       dtype='object')

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))
train_x,test_x,train_y,test_y=train_test_split(X,Y,test_size=0.2,random_state=4)
print('Shape train X',train_x.shape)
print('Shape train Y',train_y.shape)
print('Shape test X',test_x.shape)
print('Shape test Y',test_y.shape)
# Out:
# Shape train X (800, 11)
# Shape train Y (800,)
# Shape test X (200, 11)
# Shape test Y (200,)

# %% [markdown]
# ## Fit Model

# %%
from sklearn.neighbors import KNeighborsClassifier
k = 4
knnclassifier=KNeighborsClassifier(a[n_neighbors=4,mode='distance']).fit(train_x,train_y)
knnclassifier
# Out:
#   File "<ipython-input-56-4becfaf5adeb>", line 4
#     knnclassifier
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Predict Test
