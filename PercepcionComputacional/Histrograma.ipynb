# %% [markdown]
# Histrograma

# %%
import math
import numpy as np
import pandas as pd
import skimage.io as io
import matplotlib.pyplot as plt
from skimage.feature import greycomatrix, greycoprops
from skimage.util import img_as_ubyte

# %%
def imshow(img):
    fig, ax = plt.subplots(figsize=(7, 7))
    # El comando que realmente muestra la imagen
    ax.imshow(img,cmap=plt.cm.gray)
    # Para evitar que aparezcan los números en los ejes
    ax.set_xticks([]), ax.set_yticks([])
    plt.show()

# %%
img_marmol = io.imread(fname="images/marmol.png",as_gray=True)
imshow(img_marmol)
n,bins,patches=plt.hist(img_marmol.ravel(),bins=256,density=1)
print(np.sum(n))
#
#df_norm
plt.show()

#hist, bin_edges = np.histogram(a, density=True)
# Out:
# 259.1860573147403

# %%
hist, bins=np.histogram(img_marmol.ravel(), bins=256, density=True)
plt.plot(hist)

# %%
import numpy as np

# Sample from a normal distribution using numpy's random number generator
samples = img_marmol.ravel()

histogram, bins = np.histogram(samples, bins=256, density=True)

bin_centers = 0.5*(bins[1:] + bins[:-1])

# Compute the PDF on the bin centers from scipy distribution object
from scipy import stats
pdf = stats.norm.pdf(bin_centers)

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 4))
plt.plot(bin_centers, histogram, label="Histogram of samples")
plt.plot(bin_centers, pdf, label="PDF")
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n,bins,patches=plt.hist(img_marmol.ravel(),bins=256,density=1)
y = bins
plt.plot(n)
plt.show()

# %%
n, bins, patches = plt.hist(img_marmol.ravel(), bins=256)
plt.show()
n = n/len(n)
n = np.append(n, 0)
mu = np.mean(n)
sigma = np.std(n)
mu = np.mean(n)
sigma = np.std(n)
plt.bar(bins,n, width=(bins[len(bins)-1]-bins[0])/40)
y1= (1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins - mu)**2 /(2*sigma**2)))*0.03
plt.plot(bins, y1, 'r--', linewidth=2)

# %%
print(hist_norm)
# Out:
# [0.00137174 0.00137174 0.         0.00137174 0.00137174 0.00548697
#  0.00411523 0.00823045 0.01097394 0.02057613 0.0260631  0.04389575
#  0.04938272 0.05486968 0.09190672 0.12345679 0.19615912 0.21124829
#  0.3388203  0.40877915 0.46776406 0.58710562 0.60631001 0.71193416
#  0.71742112 0.84910837 0.89711934 0.91358025 0.95336077 0.92043896
#  0.96296296 0.96021948 1.         0.93278464 0.99039781 0.83676269
#  0.90534979 0.78737997 0.8600823  0.85733882 0.82853224 0.79423868
#  0.72153635 0.67215364 0.65020576 0.64060357 0.65843621 0.5473251
#  0.50891632 0.02743484 0.51577503 0.51989026 0.53772291 0.48559671
#  0.478738   0.44993141 0.42249657 0.42386831 0.42524005 0.37311385
#  0.34019204 0.35939643 0.31687243 0.2962963  0.29218107 0.2866941
#  0.24828532 0.23593964 0.23731139 0.20987654 0.20301783 0.22359396
#  0.2085048  0.17832647 0.21536351 0.18381344 0.17558299 0.18106996
#  0.13854595 0.14540466 0.12345679 0.12620027 0.11796982 0.11248285
# ...

# %%
def computeFftWavSignal(inputsignal, rate):
    # inputsignal: the signal for which the transform will be computed
    # rate: sampling frequency
    
    # Computing the Fourier transform (complex numbers list)
    signalf = fft(inputsignal)
    # Half of the fft list (real signal symmetry)
    h = len(signalf)/2
    signalf2 = abs(signalf[:(h-1)])
    # Vector of frequencies
    f = np.linspace(start=0, stop=rate/2, num=len(signalf2))
    
    r = (f, signalf2)
    
    return r
