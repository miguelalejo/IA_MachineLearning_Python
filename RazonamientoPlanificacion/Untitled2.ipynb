# %% [markdown]
# Estimado Cesar
#
# Envió mis repuestas adicionalmente adjunto dos archivos pddl con dos dominios diferentes y aquí surge la siguiente duda ya que considero que la mesa debería ir dentro de una acción diferente por ejemplo sobremesa(?bloque) . Entonces la duda es si lo recomendable es crear otra acción para representar la mesa porque considero que no debe ser tratado como bloque. Por favor puede revisarlos y enviarme sus comentarios.
# ![image.png](attachment:image.png)
#
# •	El objetivo está correctamente especificado teniendo en cuenta el enunciado?
#
# No, es necesario considerar lo que se especifica en el enunciado del ejercicio y se debe incluir sobre(A,B) ^ libre(A)
#
# •	Considera que los operadores están bien definidos?
#
# No, se debe incluir para las precondiciones  sobre(?bloque2,?Mesa) y para los efectos que libre(?bloque2)
#
# •	Asumiendo que las acciones están bien definidas. Que acciones son aplicables en el estado inicial? Para cada acción aplicable genere el estado resultante.
# Únicamente la operación MoverSobre
#
# •	Teniendo como nodo raíz el estado inicial, construye el árbol de búsqueda aplicando los algoritmos (este es un ejemplo, en el examen será solo aplicar un algoritmo, y se dirá exactamente cuál): (Tomando de referencia lo presentando en el foro)
#
# o	Anchura,
# o	Profundidad
# o	Coste Uniforme
# o	A*

# %% [markdown]
# ![image.png](attachment:image.png)
